# %% [markdown]
# <a href="https://colab.research.google.com/github/barsha0518/barsha-_ML_1st_lab_assignment/blob/main/ml_2nd_assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
wimport pandas as pd
df= pd.DataFrame()
df['Name']=['barsha','xyx','aayush','pallu']
df['age']=[20,25,18,17]
df['city']=['pune','mumbai','ayz','qyrd']
df['country']=['india','india','india','india']
df['gender']=['female','female','male','female']
print(df)
df.iloc[1:4,1:2]
#df[df['gender']=='female']
df.replace("female","women")
# Out:
#      Name  age    city country  gender
# 0  barsha   20    pune   india  female
# 1     xyx   25  mumbai   india  female
# 2  aayush   18     ayz   india    male
# 3   pallu   17    qyrd   india  female
#      Name  age    city country gender
# 0  barsha   20    pune   india  women
# 1     xyx   25  mumbai   india  women
# 2  aayush   18     ayz   india   male
# 3   pallu   17    qyrd   india  women

# %%
from google.colab import files
uplaoded = files.upload()
# Out:
#      <input type="file" id="files-9dd0e341-7668-422d-a86a-ed6692da3f14" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-9dd0e341-7668-422d-a86a-ed6692da3f14">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import io
df = pd.read_csv(io.BytesIO(uplaoded['AWCustomers.csv']))
#print(df)
x=df.drop(['Title'],axis=1)
#df.drop(['middleName'],axis=1)
print(x)
x=df.drop(['Suffix'],axis=1)
print(x)
x=df.drop(['AddressLine2'],axis=1)
print(x)
# Out:
#        CustomerID FirstName MiddleName  LastName Suffix  \
# 0           21173      Chad          C      Yuan    NaN
# 1           13249      Ryan        NaN     Perry    NaN
# 2           29350     Julia        NaN  Thompson    NaN
# 3           13503  Theodore        NaN     Gomez    NaN
# 4           22803  Marshall          J      Shan    NaN
# ...           ...       ...        ...       ...    ...
# 18356       25414     Grace          C    Bailey    NaN
# 18357       11459     Tasha        NaN      Deng    NaN
# 18358       12160    Jaclyn        NaN     Zhang    NaN
# 18359       14353      Erin          I      Reed    NaN
# 18360       16676    Amanda        NaN     Perry    NaN
#
#                  AddressLine1 AddressLine2            City  \
# 0          7090 C. Mount Hood          NaN      Wollongong
# 1         3651 Willow Lake Rd          NaN         Shawnee
# 2      1774 Tice Valley Blvd.          NaN     West Covina
# ...

# %%
import pandas as pd
import io
df = pd.read_csv(io.BytesIO(uplaoded['AWCustomers.csv']))
print(pd.isna(df))
x=df.fillna(0)
print(x)
# Out:
#        CustomerID  Title  FirstName  MiddleName  LastName  Suffix  \
# 0           False   True      False       False     False    True
# 1           False   True      False        True     False    True
# 2           False   True      False        True     False    True
# 3           False   True      False        True     False    True
# 4           False   True      False       False     False    True
# ...           ...    ...        ...         ...       ...     ...
# 18356       False   True      False       False     False    True
# 18357       False   True      False        True     False    True
# 18358       False   True      False        True     False    True
# 18359       False   True      False       False     False    True
# 18360       False   True      False        True     False    True
#
#        AddressLine1  AddressLine2   City  StateProvinceName  ...  Education  \
# 0             False          True  False              False  ...      False
# ...

# %%
import pandas as pd
import io
df = pd.read_csv(io.BytesIO(uplaoded['AWCustomers.csv']))
print(df)
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x=df['YearlyIncome']=scaler.fit_transform(df['YearlyIncome'].values.reshape(-1, 1)).flatten()
print(x)
# Out:
#        CustomerID Title FirstName MiddleName  LastName Suffix  \
# 0           21173   NaN      Chad          C      Yuan    NaN
# 1           13249   NaN      Ryan        NaN     Perry    NaN
# 2           29350   NaN     Julia        NaN  Thompson    NaN
# 3           13503   NaN  Theodore        NaN     Gomez    NaN
# 4           22803   NaN  Marshall          J      Shan    NaN
# ...           ...   ...       ...        ...       ...    ...
# 18356       25414   NaN     Grace          C    Bailey    NaN
# 18357       11459   NaN     Tasha        NaN      Deng    NaN
# 18358       12160   NaN    Jaclyn        NaN     Zhang    NaN
# 18359       14353   NaN      Erin          I      Reed    NaN
# 18360       16676   NaN    Amanda        NaN     Perry    NaN
#
#                  AddressLine1 AddressLine2            City  \
# 0          7090 C. Mount Hood          NaN      Wollongong
# 1         3651 Willow Lake Rd          NaN         Shawnee
# ...

# %%
import numpy as np
#df = pd.read_csv(io.BytesIO(uplaoded['AWCustomers.csv']))
object1=np.array([1,0,1,1,0,1])
object2=np.array([1,1,1,1,0,0])
def simple_matching_coeff(vec1,vec2):
  matches=np.sum(vec1==vec2)
  return matches/len(vec1)
print(simple_matching_coeff(object1,object2))
# Out:
# 0.6666666666666666

# %%
import numpy as np

def jaccard_similarity(x,y):
  intersection=np.logical_and(x,y)
  union=np.logical_or(x,y)
  similarity=intersection.sum()/float(union.sum())
  return similarity
  x = [0,1,0,0,0,1,0,0,1]
  y = [0,1,1,0,0,1,0,0,1]

  simxy=jaccard_similarity(x,y)

  print(' Similarity between x and y is', simxy)
